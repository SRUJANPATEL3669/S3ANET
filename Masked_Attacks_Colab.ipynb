# %% [markdown]
# # Masked L2 Attacks (Saliency Based) for S3ANet
#
# This notebook clones the `SBP` branch of the S3ANet repository and runs the masked adversarial attacks (PGD, I-FGSM, FGSM) which restrict noise to the top $N$ most salient physical spectral bands.

# %%
# !git clone -b SBP https://github.com/SRUJANPATEL3669/S3ANET.git
# %cd S3ANET
# !pip install -r requirements.txt  # If requirements.txt exists, otherwise install dependencies manually

# %%
# !pip install einops pandas numpy matplotlib

# %% [markdown]
# ### Run Masked PGD Attack (Restricted to Top 10 Bands)

# %%
# !python Run_Masked_Attacks.py --dataID 1 --attack_type PGD --top_N 10 --epsilon 0.04 --epoch 100

# %% [markdown]
# ### Compare with Masked I-FGSM Attack

# %%
# !python Run_Masked_Attacks.py --dataID 1 --attack_type IFGSM --top_N 10 --epsilon 0.04 --epoch 100

# %% [markdown]
# ### View Results

# %%
import pandas as pd
df = pd.read_excel('Exp_PaviaU/Masked_PGD_Metrics_Results.xlsx')
display(df)
